# %%
#Aug 23

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Step 1
df1=pd.read_csv('mobile_prices.csv')
df1
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33561.0
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77128.0
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15175.0
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22621.0
# 4                POCO C51 (Power Black, 64 GB)         4.3            15175.0
# ...                                        ...         ...                ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25582.0
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25582.0
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25582.0
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7117.0
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15701.0
#
# ...

# %%
df1.head(5)
# Out:
#                       Phone Name  Rating ?/5  Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33561.0  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77128.0  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15175.0  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22621.0  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15175.0  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# ...

# %%
df1.tail(5)
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25582.0
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25582.0
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25582.0
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7117.0
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15701.0
#
#            RAM ROM/Storage                     Back/Rare Camera  \
# 1831  4 GB RAM   64 GB ROM    48MP + 2MP + 2MP + AI Lens Camera
# 1832  4 GB RAM   64 GB ROM    48MP + 2MP + 2MP + AI Lens Camera
# 1833  4 GB RAM   64 GB ROM    48MP + 2MP + 2MP + AI Lens Camera
# 1834  8 GB RAM  128 GB ROM    48MP + 8MP + 2MP + AI Lens Camera
# 1835  4 GB RAM   64 GB ROM  16MP + 5MP + 2MP + Low Light Sensor
#
#                       Front Camera   Battery                      Processor  \
# ...

# %%
df1.info()

#dtype - Object - catogorical
#      - Int - numerical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1836 entries, 0 to 1835
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Phone Name         1836 non-null   object
#  1   Rating ?/5         1836 non-null   float64
#  2   Number of Ratings  1836 non-null   float64
#  3   RAM                1836 non-null   object
#  4   ROM/Storage        1662 non-null   object
#  5   Back/Rare Camera   1827 non-null   object
#  6   Front Camera       1435 non-null   object
#  7   Battery            1826 non-null   object
#  8   Processor          1781 non-null   object
#  9   Price in INR       1836 non-null   object
#  10  Date of Scraping   1836 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 157.9+ KB

# %%
df1.isnull().sum()
# Out:
# Phone Name             0
# Rating ?/5             0
# Number of Ratings      0
# RAM                    0
# ROM/Storage          174
# Back/Rare Camera       9
# Front Camera         401
# Battery               10
# Processor             55
# Price in INR           0
# Date of Scraping       0
# dtype: int64

# %%
df1.describe()
# Out:
#         Rating ?/5  Number of Ratings
# count  1836.000000       1.836000e+03
# mean      4.210512       4.669473e+04
# std       0.543912       9.756649e+04
# min       0.000000       0.000000e+00
# 25%       4.200000       1.313000e+03
# 50%       4.300000       8.391000e+03
# 75%       4.400000       4.149500e+04
# max       4.800000       1.342530e+06

# %%
#step 2
'''Data Cleaning 
1.Filling null values 
2.Droping the null values 
3.Dropping th ecolumns containing null value'''

#Drop a Null values - to dropa null value null value% should be < 5% -- performed using dropna

#Drop a cloumn -when null values are > 50% --drop(col_name)

#Fill null values - when its between 5 & 50 % -- fillna()
#Types of fill - bfill-- copies the prev data entry 
#              - ffill -- copies the next vlaue entry in the column 

#Usually data is filled via 
# MEan /  median for numerical data
# Median is used when outliers are present in the data else mean is taken

# median for catagorical data
# Out:
# 'Data Cleaning \n1.Filling null values \n2.Droping the null values \n3.Dropping th ecolumns containing null values'

# %%
df1.boxplot()
# Out:
# <AxesSubplot:>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1836 entries, 0 to 1835
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Phone Name         1836 non-null   object
#  1   Rating ?/5         1836 non-null   float64
#  2   Number of Ratings  1836 non-null   float64
#  3   RAM                1836 non-null   object
#  4   ROM/Storage        1662 non-null   object
#  5   Back/Rare Camera   1827 non-null   object
#  6   Front Camera       1435 non-null   object
#  7   Battery            1826 non-null   object
#  8   Processor          1781 non-null   object
#  9   Price in INR       1836 non-null   object
#  10  Date of Scraping   1836 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 157.9+ KB
