# %% [markdown]
# # EDA : Step by Step

# %% [markdown]
# ## 1.Data Sourcing
# ### Data collection/GAthering/Ingestion

# %%
#importing libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001002    Male      No          0      Graduate
# 1             1  LP001003    Male     Yes          1      Graduate
# 2             2  LP001005    Male     Yes          0      Graduate
# 3             3  LP001006    Male     Yes          0  Not Graduate
# 4             4  LP001008    Male      No          0      Graduate
# ..          ...       ...     ...     ...        ...           ...
# 615         609  LP002978  Female      No          0      Graduate
# 616         610  LP002979    Male     Yes         3+      Graduate
# 617         611  LP002983    Male     Yes          1      Graduate
# 618         612  LP002984    Male     Yes          2      Graduate
# 619         613  LP002990  Female      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No            58490                0.0         NaN
# ...

# %% [markdown]
# #### Investigaton of Structure

# %%
df.size
# Out:
# 8680

# %%
df.shape
# Out:
# (620, 14)

# %%
df.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001002   Male      No          0      Graduate            No
# 1           1  LP001003   Male     Yes          1      Graduate            No
# 2           2  LP001005   Male     Yes          0      Graduate           Yes
# 3           3  LP001006   Male     Yes          0  Not Graduate            No
# 4           4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            58490                0.0         NaN             360.0
# 1            45830            15080.0   1280000.0             360.0
# 2            30000                0.0    660000.0             360.0
# 3            25830            23580.0   1200000.0             360.0
# 4            60000                0.0   1410000.0             360.0
#
#    Credit_History Property_Area Loan_Status
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents Education Self_Employed  \
# 615         609  LP002978  Female      No          0  Graduate            No
# 616         610  LP002979    Male     Yes         3+  Graduate            No
# 617         611  LP002983    Male     Yes          1  Graduate            No
# 618         612  LP002984    Male     Yes          2  Graduate            No
# 619         613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 615            29000                0.0    710000.0             360.0
# 616            41060                0.0    400000.0             180.0
# 617            80720             2400.0   2530000.0             360.0
# 618            75830                0.0   1870000.0             360.0
# 619            45830                0.0   1330000.0             360.0
#
#      Credit_History Property_Area Loan_Status
# ...

# %%
#for genrating a random value from the dataset
df.sample()
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 270         264  LP001872   Male      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 270            51660                0.0   1280000.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 270             1.0     Semiurban           Y

# %%
#to find duplicate values in set we r checking 1st 50 rows
df.head(50)
# Out:
#     Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0            0  LP001002    Male      No          0      Graduate
# 1            1  LP001003    Male     Yes          1      Graduate
# 2            2  LP001005    Male     Yes          0      Graduate
# 3            3  LP001006    Male     Yes          0  Not Graduate
# 4            4  LP001008    Male      No          0      Graduate
# 5            5  LP001011    Male     Yes          2      Graduate
# 6            6  LP001013    Male     Yes          0  Not Graduate
# 7            7  LP001014    Male     Yes         3+      Graduate
# 8            8  LP001018    Male     Yes          2      Graduate
# 9            9  LP001020    Male     Yes          1      graduate
# 10          10  LP001024    Male     Yes          2      Graduate
# 11          10  LP001024    Male     Yes          2      Graduate
# 12          11  LP001027    Male     Yes          2      graduate
# ...

# %% [markdown]
# #### Investigation of Quality

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 620 entries, 0 to 619
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         620 non-null    int64
#  1   Loan_ID            620 non-null    object
#  2   Gender             607 non-null    object
#  3   Married            617 non-null    object
#  4   Dependents         605 non-null    object
#  5   Education          620 non-null    object
#  6   Self_Employed      587 non-null    object
#  7   ApplicantIncome    620 non-null    int64
#  8   CoapplicantIncome  620 non-null    float64
#  9   LoanAmount         598 non-null    float64
#  10  Loan_Amount_Term   606 non-null    float64
#  11  Credit_History     569 non-null    float64
#  12  Property_Area      620 non-null    object
#  13  Loan_Status        620 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 67.9+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome    LoanAmount  \
# count  620.000000       620.000000         620.000000  5.980000e+02
# mean   303.730645     53908.483871       16179.143871  1.460385e+06
# std    178.742692     60861.304704       29136.617959  8.541896e+05
# min      0.000000      1500.000000           0.000000  9.000000e+04
# 25%    148.750000     28757.500000           0.000000  1.000000e+06
# 50%    303.500000     38060.000000       11490.000000  1.275000e+06
# 75%    458.250000     57850.000000       22877.500000  1.677500e+06
# max    613.000000    810000.000000      416670.000000  7.000000e+06
#
#        Loan_Amount_Term  Credit_History
# count        606.000000      569.000000
# mean         341.782178        0.841828
# std           65.442363        0.365223
# min           12.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  Loan_ID  Gender  Married  Dependents  Education  \
# 0         False    False   False    False       False      False
# 1         False    False   False    False       False      False
# 2         False    False   False    False       False      False
# 3         False    False   False    False       False      False
# 4         False    False   False    False       False      False
# ..          ...      ...     ...      ...         ...        ...
# 615       False    False   False    False       False      False
# 616       False    False   False    False       False      False
# 617       False    False   False    False       False      False
# 618       False    False   False    False       False      False
# 619       False    False   False    False       False      False
#
#      Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0            False            False              False        True
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        33
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       51
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Unnamed: 0           0.00
# Loan_ID              0.00
# Gender               2.10
# Married              0.48
# Dependents           2.42
# Education            0.00
# Self_Employed        5.32
# ApplicantIncome      0.00
# CoapplicantIncome    0.00
# LoanAmount           3.55
# Loan_Amount_Term     2.26
# Credit_History       8.23
# Property_Area        0.00
# Loan_Status          0.00
# dtype: float64

# %%
data=df.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 614 entries, 0 to 619
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         614 non-null    int64
#  1   Loan_ID            614 non-null    object
#  2   Gender             601 non-null    object
#  3   Married            611 non-null    object
#  4   Dependents         599 non-null    object
#  5   Education          614 non-null    object
#  6   Self_Employed      582 non-null    object
#  7   ApplicantIncome    614 non-null    int64
#  8   CoapplicantIncome  614 non-null    float64
#  9   LoanAmount         592 non-null    float64
#  10  Loan_Amount_Term   600 non-null    float64
#  11  Credit_History     564 non-null    float64
#  12  Property_Area      614 non-null    object
#  13  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 72.0+ KB

# %%
data.sample()
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents Education Self_Employed  \
# 462         456  LP002459   Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 462            43010                0.0   1180000.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 462             1.0         Urban           Y

# %% [markdown]
# ### Univariate Visualization

# %% [markdown]
# ##### A.Numerical Features

# %%
plt.hist(data['Loan_Amount_Term'])
# Out:
# (array([  3.,   6.,   3.,  44.,   4.,   0.,  13., 512.,   0.,  15.]),
#  array([ 12. ,  58.8, 105.6, 152.4, 199.2, 246. , 292.8, 339.6, 386.4,
#         433.2, 480. ]),
#  <BarContainer object of 10 artists>)

# %%
numerical_features = ['Loan_Amount_Term','LoanAmount','CoapplicantIncome']
data[numerical_features].hist(figsize=(10,4))
# Out:
# array([[<AxesSubplot:title={'center':'Loan_Amount_Term'}>,
#         <AxesSubplot:title={'center':'LoanAmount'}>],
#        [<AxesSubplot:title={'center':'CoapplicantIncome'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ##### Boxplot : Summarization/ Outlier Detection

# %%
plt.boxplot(data['ApplicantIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13438d032b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x13438d03850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x13438cf4fa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13438d03df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13438d11100>],
#  'means': []}

# %%
plt.violinplot(data['CoapplicantIncome'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1343903f0d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x13438d243d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1343903f7c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1343903fb80>}

# %% [markdown]
# ##### B.Categorical variable

# %%
data.sample(10)
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 238         232  LP001770    Male      No          0  Not Graduate
# 309         303  LP001977    Male     Yes          1      Graduate
# 35           29  LP001087  Female      No          2      Graduate
# 263         257  LP001854    Male     Yes         3+      Graduate
# 619         613  LP002990  Female      No          0      Graduate
# 455         449  LP002444    Male      No          1  Not Graduate
# 329         323  LP002055  Female      No          0      Graduate
# 38           32  LP001097    Male      No          1      Graduate
# 391         385  LP002237    Male      No          1      Graduate
# 287         281  LP001914    Male     Yes          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 238            No            31890            25980.0   1200000.0
# 309            No            16250            18030.0    960000.0
# ...

# %%
sns.countplot(data=data,x='Gender')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
dependents = data['Dependents'].value_counts()
plt.pie(dependents.values, labels = dependents.index, autopct = '%1.1f%')
plt.title("Dependents Distribution")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23060\3535048532.py in <module>
#       1 dependents = data['Dependents'].value_counts()
# ----> 2 plt.pie(dependents.values, labels = dependents.index, autopct = '%1.1f%')
#       3 plt.title("Dependents Distribution")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### 1.Numerical to Numerical

# %%
#Scatter plot

plt.scatter(data['ApplicantIncome'],data['LoanAmount'])
plt.xlabel('Applicant Income')
plt.ylabel('LoanAmount')
plt.show()

# %%
sns.scatterplot(data=data,x='ApplicantIncome', y ='LoanAmount')
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
#Joint Plot using Seaborn 

sns.jointplot(data=data,x='LoanAmount', y='ApplicantIncome', kind='scatter')
plt.suptitle('Joint Plot')
# Out:
# Text(0.5, 0.98, 'Joint Plot')

# %% [markdown]
# #### Categorical to Categorical

# %%
# Count Plot

sns.countplot(data=data,x='Gender', hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=data,x='Married', hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
sns.countplot(data=data,x='Education', hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(data=data,x='Property_Area', hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %% [markdown]
# #### Categorical & Numerical

# %%
#Bar plot
# categorical on x & numeerical on y
sns.barplot(data=data,x='Gender',y='ApplicantIncome')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='ApplicantIncome'>

# %%
sns.barplot(data=data,x='Gender',y='LoanAmount')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
#Multivariate
sns.barplot(data=data,x='Gender',y='ApplicantIncome', hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='ApplicantIncome'>

# %%
#Box plot

sns.boxplot(data=data,x='Education',y='ApplicantIncome')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='ApplicantIncome'>

# %%
sns.boxplot(data=data,x='Education',y='LoanAmount')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %%
sns.boxplot(data=data,x='Married',y='LoanAmount')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='LoanAmount'>

# %%
#Violin plot

sns.violinplot(data=data,x='Education',y='LoanAmount')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %%
sns.boxplot(data=data,x='Gender',y='LoanAmount')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
sns.boxplot(data=data,x='Married',y='LoanAmount')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='LoanAmount'>

# %%
#Distribution plot

sns.displot(data=data,hue='Education',x='LoanAmount')

# %%
sns.displot(data=data,x='LoanAmount',hue='Education',kind='kde')

# %%
sns.displot(data=data,x='LoanAmount',hue='Married',kind='kde')

# %%
# Barplot

sns.barplot(data=data,y='LoanAmount',x='Education',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='LoanAmount'>

# %% [markdown]
# ### Multivariate Alaysis

# %%
#Pair plot

sns.pairplot(data=data,vars=['ApplicantIncome','Gender','Education'])

# %%
#Heat Map

data2=data.select_dtypes(include=np.number)
sns.heatmap(data2.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.hist(bins=50,figsize=[12,8])
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'ApplicantIncome'}>],
#        [<AxesSubplot:title={'center':'CoapplicantIncome'}>,
#         <AxesSubplot:title={'center':'LoanAmount'}>],
#        [<AxesSubplot:title={'center':'Loan_Amount_Term'}>,
#         <AxesSubplot:title={'center':'Credit_History'}>]], dtype=object)
